# %%
import numpy as np
from itertools import combinations
from itertools import permutations
from scipy import stats
from urllib import request
import re
import pandas as pd

# %% [markdown]
# # Введение
#
# В данном ТЗ описывается инструмент автоматического поиска популярных тегов и пометки ими запросов из загруженного ядра. Основной задачей инструмента является подготовка файла для оценки видимости. Кроме того, приведён примерный код, реализующий данный функционал. Код написан для того чтобы протестировать идею сервиса и не является образцом хорошего програмирования.
#
# Сервис разбивает ключевые слова на 1-2 и 3х словные сочетания, находит устойчивые  двусловные и трехсловные сочетания, после чего помечает запросы тегми - однословными + устойчивыми двусловными и трёхсловными сочетаниями

# %% [markdown]
# # Категории
#
# Весь описаный ниже процесс выполняется отдельно для каждой категории. В данном примере во входном файле только одна категория, но вам необходимо дать пользователю возможность загрузить список запросов для многих категорий, помеченных названиями категорий в формате:
#
# ключевое слово 1 ; категория 1
#
# ключевое слово 2 ; категория 1
#
# ключевое слово 3 ; категория 2
#
# и так далее.

# %% [markdown]
# # Лемматизируем и чистим запросы
#
# В терминале используя майтем:  $mystem -c -l -d input.txt output.txt
#
# Список лемматизированных запросов далее используется для поиска и привязки тегов, но пользователю сервиса нужно будет отдать список запросов точно в такой-же форме, в какой они были получены из базы.

# %%
#Загрузка файла с запросами, где все слова приведены к исходной словоформе.
qfile = open('../divanylem.txt', 'r', encoding = "utf-8").read().split('\n')
#qfile = open('../platyalem.txt', 'r', encoding = "utf-8").read().split('\n')

# %%
qfile[2:7]
# Out:
# ['2 {х} {местный} {диван} {кровать}',
#  '31 {диван} {для} {офис}',
#  '32 {диван} {офисный}',
#  '33 {купить} {диван}',
#  '35 {диван} {еврокнижка?}']

# %%
#Удаление ненужных символов
def clean_queries(qlist, regexp_delete, regexp_use = ''):
    for i in range(len(qlist)):
        qlist[i] = re.sub(regexp_delete, regexp_use, qlist[i])

clean_queries(qfile, '[?{}}]', "")

# %%
qfile[2:7]
# Out:
# ['2 х местный диван кровать',
#  '31 диван для офис',
#  '32 диван офисный',
#  '33 купить диван',
#  '35 диван еврокнижка']

# %% [markdown]
# # Подсчёт встречаемости слов и 2-3-словных сочетаний
#
# По полученному списку запросов, необходимо посчитать сколько раз встречаются отдельные слова и 2-3 словные сочетания. Будем считать, что слова являются сочетанием, если они находятся в одном запросе, не зависимо от порядка и близости из относительно друг-друга. Но за то, что слова идут друг за другом, можно дать им дополнительный балл. Например, считать что если 2 слова встретились в одном запросе, то пара слов получает 1 балл, а если встретились подряд - 2 балла. Порядок учитывать не нужно.

# %%
def count_ngrams(keywords, smallest, comb_size=1, bonus = 2,
                stop_words = []):
    """
    keywords - список ключевиков
    smallest - частотность самого редкого сочетания/слова на выходе
    comb_size - 1 для того чтобы посчитать однословники, 2 - двусловники и так далее.
    bonus - сколько баллов получает словосочетание, если его слова идут друг за другом в запросе.
    stop_words - слова, не включаемые в рассчёт.
    """
    if comb_size == 1:
        #список униграм
        index = {}
        for line in keywords:
            for word in line.split():
                if word in index:
                    index[word] +=1
                else:
                    if word not in stop_words:
                        index[word] = 1  
    else:
        index = {}
        for line in keywords:
            #Каждая ключевая фраза разбивается на слова и этот список слов сортируется, для того чтобы избежать повторений
            #и считать сочетания слов в разном порядке как одно.
            line_list = line.split()
            line_list.sort()
            for comb in combinations(line_list, comb_size):
                if comb in index:
                    #Важный момент! при проверке не идут ли слова подряд, используются все возможные варианты порядка слов
                    perms = [' '.join(perm) for perm in permutations(comb, comb_size)]
                    j = 0
                    for perm in perms:
                        if perm in line:
                            index[comb] += bonus
                            j == 1
                            break
                    if j == 0:
                        index[comb] +=1
                else:
                    s = 0
                    for word in comb:
                        if word in stop_words:
                            s += 1
                    if s == 0:
                        index[comb] = 1
    
    #удаление слов/словосочетаний которые встречаются реже чем smallest
    index_clean = {}
    for ngram in index:
        if index[ngram] >= smallest:
            index_clean[ngram] = index[ngram]
   
    return index_clean

# %%
stop_words = ['с','в','на','от','к','за','до','под','над','со','и', 'из', 'по', 'а', 'где', 'для']

ngrams1 = count_ngrams(qfile, smallest= 1, comb_size = 1, bonus = 2, stop_words=stop_words)
ngrams2 = count_ngrams(qfile, smallest = 15, comb_size = 2, bonus = 2, stop_words=stop_words)
ngrams3 = count_ngrams(qfile, smallest = 10, comb_size = 3, bonus = 2, stop_words=stop_words)

# %% [markdown]
# Получили списки слов и сочетаний с оценками встречаемости в загруженной семантике

# %%
ngrams1
# Out:
# {'03': 1,
#  '04': 1,
#  '05': 1,
#  '06': 1,
#  '07': 1,
#  '1': 4,
#  '10': 1,
#  '100': 3,
#  '10000': 1,
#  '11': 2,
#  '12': 1,
#  '120': 2,
#  '180': 1,
#  '2': 18,
#  '200': 3,
#  '200х200': 1,
#  '25': 1,
#  '26': 1,
#  '2х': 1,
#  '3': 13,
#  '300': 2,
#  '31': 1,
#  '32': 1,
#  '33': 1,
#  '35': 1,
#  '36': 1,
#  '37': 1,
#  '38': 1,
#  '39': 1,
#  '3х': 1,
#  '4': 2,
#  '400': 1,
#  '5': 1,
#  '500': 1,
#  '5000': 1,
#  '600': 1,
#  '68566': 1,
#  '7': 1,
#  '8': 3,
#  '9': 1,
#  'a': 5,
#  'advance': 1,
#  'airon': 1,
#  'alecto': 1,
#  'alivar': 1,
#  'amika': 1,
#  'angelo': 1,
#  'arketipo': 1,
#  'ashley': 3,
#  'baker': 1,
#  'bangkok': 1,
#  'baxter': 3,
#  'bedding': 1,
#  'bentley': 1,
#  'bestway': 1,
#  'bm': 1,
#  'bo': 8,
#  'bodema': 1,
#  'bonaldo': 3,
#  'box': 8,
#  'busnelli': 1,
#  'c': 2,
#  'cappellini': 1,
#  'caspani': 1,
#  'chelini': 1,
#  'chester': 2,
#  'chesterfield': 1,
#  'circle': 1,
#  'conca': 1,
#  'corniche': 1,
#  'country': 1,
#  'cousins': 2,
#  'cts': 1,
#  'cube': 1,
#  'de': 1,
#  'domingo': 2,
#  'duresta': 2,
#  'ego': 1,
#  'eichholtz': 1,
#  'ella': 1,
#  'eva': 1,
#  'evanty': 1,
#  'evolution': 1,
#  'flexform': 2,
#  'formerin': 2,
#  'gala': 2,
#  'goldconfort': 1,
#  'granada': 1,
#  'hamilton': 1,
#  'il': 2,
#  'intex': 3,
#  'istambul': 1,
#  'jesse': 1,
#  'kensington': 1,
#  'keoma': 1,
#  'kroford': 1,
#  'lane': 1,
#  'las': 1,
#  'les': 2,
#  'libro': 1,
#  'ligne': 2,
#  'loft': 2,
#  'longhi': 1,
#  'maison': 1,
#  'matrix': 1,
#  'meridiani': 1,
#  'mika': 1,
#  'mix': 1,
#  'mobel': 6,
#  'mobilier': 1,
#  'moda': 2,
#  'modool': 2,
#  'monza': 1,
#  'moon': 4,
#  'morning': 1,
#  'neo': 1,
#  'new': 1,
#  'nice': 1,
#  'oelsa': 1,
#  'onda': 1,
#  'orleans': 1,
#  'oslo': 1,
#  'palatino': 1,
#  'pigoli': 1,
#  'plaza': 1,
#  'poltromot': 2,
#  'pompei': 1,
#  'prime': 1,
#  'princess': 1,
#  'provasi': 2,
#  'pushe': 4,
#  'rolf': 1,
#  'roset': 2,
#  'saiwala': 1,
#  'salotti': 3,
#  'sapapa': 1,
#  'scope': 1,
#  'selva': 1,
#  'seville': 1,
#  'smania': 2,
#  'softy': 2,
#  'soho': 1,
#  'stolline': 1,
#  'style': 1,
#  'summit': 2,
#  'swan': 1,
#  'tanagra': 1,
#  'time': 1,
#  'tino': 1,
#  'togo': 1,
#  'turri': 1,
#  'ulivi': 2,
#  'v': 6,
#  'v400': 1,
#  'valensiya': 1,
#  'vegas': 1,
#  'vibieffe': 1,
#  'zanaboni': 1,
#  'zeit': 6,
#  'авторский': 1,
#  'адам': 1,
#  'адванс': 1,
#  'адель': 1,
#  'азия': 1,
#  'аккордеон': 81,
#  'аккордион': 1,
#  'акция': 3,
#  'алабама': 1,
#  'алекс': 1,
#  'алекто': 1,
#  'алиа': 1,
#  'алий': 1,
#  'аллегро': 5,
#  'алый': 4,
#  'алькантар': 1,
#  'альмагро': 1,
#  'амбра': 2,
#  'америка': 2,
#  'американский': 1,
#  'амстердам': 16,
#  'английский': 7,
#  'англия': 1,
#  'анталия': 1,
#  'антикварный': 3,
#  'аполло': 2,
#  'арена': 2,
#  'аренда': 5,
#  'арпатек': 1,
#  'арт': 2,
#  'архангельск': 2,
#  'ассортимент': 1,
#  'астана': 1,
#  'астра': 4,
#  'атланта': 4,
#  'атлантик': 2,
#  'б': 2,
#  'бабочка': 1,
#  'бавария': 1,
#  'балашиха': 1,
#  'балдахин': 1,
#  'банк': 1,
#  'банкетка': 1,
#  'бар': 19,
#  'барный': 1,
#  'барокко': 1,
#  'барон': 5,
#  'барселона': 2,
#  'бархат': 1,
#  'баттерфляй': 1,
#  'баян': 1,
#  'беби': 2,
#  'беверли': 1,
#  'бежевый': 6,
#  'без': 20,
#  'бекер': 1,
#  'белла': 1,
#  'белоруссия': 26,
#  'белорусский': 31,
#  'белый': 35,
#  'белье': 1,
#  'бельевой': 1,
#  'бентли': 1,
#  'берлингтон': 1,
#  'берн': 1,
#  'бескаркасный': 5,
#  'бестер': 1,
#  'бизнес': 2,
#  'бизон': 3,
#  'бирмингем': 1,
#  'бирюзовый': 2,
#  'благо': 2,
#  'блок': 15,
#  'блэквуд': 1,
#  'блюз': 4,
#  'блюз2': 1,
#  'блюз3': 1,
#  'бобокс': 2,
#  'больница': 1,
#  'большой': 30,
#  'бордо': 1,
#  'бордовый': 1,
#  'борнхельм': 1,
#  'борович': 14,
#  'бортик': 2,
#  'бостон': 8,
#  'боттичелли': 1,
#  'брайт': 1,
#  'брейвуд': 1,
#  'брест': 2,
#  'брисия': 1,
#  'бристоль': 12,
#  'бруклин': 7,
#  'бруно': 1,
#  'брюссель': 3,
#  'бу': 9,
#  'ва': 1,
#  'вавилон': 4,
#  'валенсия': 5,
#  'валерий': 1,
#  'варшава': 1,
#  'ваш': 1,
#  'вега': 2,
#  'вегас': 4,
#  'вейт': 3,
#  'велюр': 1,
#  'венеция': 1,
#  'верона': 4,
#  'викториола': 1,
#  'винтажный': 2,
#  'виола': 1,
#  'висмар': 1,
#  'владивосток': 3,
#  'владимир': 3,
#  'во': 4,
#  'волгоград': 1,
#  'воронеж': 7,
#  'восстановление': 1,
#  'встраивать': 1,
#  'вудкрафт': 1,
#  'выбирать': 3,
#  'вывоз': 2,
#  'выдвижной': 3,
#  'выкатной': 51,
#  'высокий': 3,
#  'вэлбек': 1,
#  'г': 1,
#  'гала': 2,
#  'галл': 2,
#  'гамбург': 1,
#  'гамма': 2,
#  'ганновер': 1,
#  'гейша': 1,
#  'германия': 12,
#  'глобус': 1,
#  'гном': 1,
#  'гобелен': 2,
#  'гобеленовый': 2,
#  'год': 2,
#  'голливуд': 1,
#  'голубой': 2,
#  'гольфстрим': 1,
#  'гомель': 2,
#  'горчичный': 3,
#  'гостиная': 32,
#  'гостиница': 3,
#  'готовый': 3,
#  'грация': 1,
#  'грузчик': 1,
#  'дайтон': 4,
#  'дакар': 1,
#  'даллас': 3,
#  'дача': 8,
#  'даша': 1,
#  'двойной': 2,
#  'двуспальный': 2,
#  'двухместный': 32,
#  'двухъярусный': 6,
#  'девочка': 3,
#  'деко': 2,
#  'декоративный': 5,
#  'дельфа': 1,
#  'дельфин': 16,
#  'день': 2,
#  'дерево': 4,
#  'деревянный': 13,
#  'детский': 128,
#  'дешево': 80,
#  'дешевый': 46,
#  'джинсовый': 1,
#  'джокер': 1,
#  'диана': 2,
#  'диван': 4310,
#  'дизайн': 3,
#  'дизайнер': 1,
#  'дизайнерский': 11,
#  'диксон': 2,
#  'димочка': 2,
#  'дом': 34,
#  'домашний': 1,
#  'доминго': 1,
#  'домино': 8,
#  'домодедово': 1,
#  'домодедовский': 2,
#  'дон': 1,
#  'дорого': 7,
#  'дорогой': 18,
#  'доставка': 4,
#  'дрим': 2,
#  'дуб': 2,
#  'дублин': 1,
#  'дуглас': 2,
#  'дуэт': 3,
#  'ева': 2,
#  'евро': 2,
#  'еврокнижка': 76,
#  'европа': 2,
#  'еврософ': 4,
#  'ежедневный': 1,
#  'екатеринбург': 18,
#  'елена': 1,
#  'жаккард': 1,
#  'железнодорожный': 1,
#  'желтый': 1,
#  'жидкий': 2,
#  'заказ': 80,
#  'заказчик': 1,
#  'заказывать': 17,
#  'зал': 2,
#  'зам': 1,
#  'замена': 4,
#  'заменять': 1,
#  'замша': 2,
#  'зейт': 1,
#  'зеленый': 10,
#  'золотистый': 3,
#  'золотой': 1,
#  'зона': 2,
#  'ивантеевка': 1,
#  'ижевск': 1,
#  'ижмебель': 2,
#  'изготавливать': 1,
#  'изготовление': 10,
#  'израиль': 1,
#  'икеа': 4,
#  'или': 1,
#  'император': 1,
#  'империал': 2,
#  'импортный': 5,
#  'индивидуальный': 5,
#  'индонезия': 2,
#  'интекс': 1,
#  'интер': 2,
#  'интернет': 103,
#  'интерьер': 2,
#  'ипать': 1,
#  'ирина': 1,
#  'искусственный': 5,
#  'испания': 2,
#  'испанский': 2,
#  'италия': 41,
#  'итальянский': 52,
#  'итон': 1,
#  'йорк': 1,
#  'кабинет': 7,
#  'кабуки': 1,
#  'каждый': 1,
#  'казань': 5,
#  'каир': 1,
#  'как': 2,
#  'какой': 3,
#  'калипсо': 2,
#  'калиста': 1,
#  'калифорния': 3,
#  'камчатский': 2,
#  'кантри': 3,
#  'капучино': 2,
#  'караганда': 1,
#  'карелия': 3,
#  'каркас': 3,
#  'карпентер': 1,
#  'картинка': 1,
#  'каталог': 56,
#  'кафе': 48,
#  'качели': 3,
#  'качественный': 6,
#  'квадро': 4,
#  'кватро': 1,
#  'кельн': 4,
#  'киев': 19,
#  'кинотеатр': 2,
#  'китай': 11,
#  'китайский': 6,
#  'клаб': 4,
#  'класс': 17,
#  'классика': 7,
#  'классический': 17,
#  'клеопатра': 1,
#  'клерк': 6,
#  'клик': 33,
#  'клифорд': 1,
#  'клуб': 3,
#  'кляк': 34,
#  'книжка': 66,
#  'кованый': 9,
#  'ковер': 1,
#  'ковров': 2,
#  'кожа': 29,
#  'кожаный': 209,
#  'кожать': 1,
#  'кожзам': 38,
#  'кожзаменитель': 7,
#  'комната': 12,
#  'компакт': 1,
#  'компактный': 2,
#  'комплект': 1,
#  'континент': 1,
#  'коридор': 1,
#  'коричневый': 3,
#  'кормак': 3,
#  'король': 4,
#  'корфу': 1,
#  'который': 1,
#  'красивый': 2,
#  'краснодар': 5,
#  'красноярск': 8,
#  'красный': 14,
#  'красота': 5,
#  'креативный': 2,
#  'кредит': 3,
#  'кремовый': 1,
#  'кресло': 45,
#  'кровать': 152,
#  'крофорд': 1,
#  'круглый': 17,
#  'куб': 1,
#  'купер': 1,
#  'купить': 829,
#  'курск': 3,
#  'кухня': 160,
#  'кухонный': 88,
#  'кушетка': 3,
#  'лабиринт': 3,
#  'лагуна': 8,
#  'ладья': 2,
#  'ласа': 1,
#  'латт': 1,
#  'лаунжа': 1,
#  'легион': 1,
#  'лежак': 1,
#  'лейпциг': 1,
#  'леон': 2,
#  'лерид': 1,
#  'ливерпуль': 4,
#  'лидер': 1,
#  'лидия': 1,
#  'лилия': 2,
#  'лиловый': 1,
#  'лилу': 1,
#  'лион': 6,
#  'липецк': 5,
#  'лира': 1,
#  'лиссабон': 1,
#  'лит': 5,
#  'лодочка': 1,
#  'лоза': 1,
#  'лофт': 2,
#  'люберцы': 2,
#  'люкс': 5,
#  'м': 1,
#  'магазин': 139,
#  'мадрид': 9,
#  'мажор': 1,
#  'майами': 2,
#  'малазийский': 2,
#  'малайзия': 14,
#  'маленький': 69,
#  'малиновый': 1,
#  'малогабаритный': 12,
#  'малый': 1,
#  'малыш': 1,
#  'мальта': 10,
#  'мальчик': 2,
#  'малютка': 1,
#  'манго': 1,
#  'манхеттен': 6,
#  'манчестер': 7,
#  'марианна': 1,
#  'марио': 1,
#  'маритайм': 2,
#  'марракеш': 3,
#  'марсель': 9,
#  'март': 2,
#  'марта': 1,
#  'массив': 6,
#  'мат': 1,
#  'матрас': 46,
#  'матрикс': 3,
#  'махаон': 1,
#  'машина': 1,
#  'машинка': 1,
#  'маэстро': 1,
#  'мебель': 80,
#  'мебельный': 5,
#  'мед': 1,
#  'медицинский': 5,
#  'местный': 21,
#  'место': 100,
#  'металлический': 2,
#  'металлокаркас': 15,
#  'метро': 16,
#  'мех': 3,
#  'механизм': 22,
#  'меховой': 6,
#  'мидвилы': 1,
#  'мик': 1,
#  'микроавтобус': 2,
#  'микрофибра': 1,
#  'микрофибры': 1,
#  'микс': 1,
#  'милан': 5,
#  'милано': 1,
#  'миллениум': 5,
#  'милфорд': 1,
#  'мини': 16,
#  'минск': 1,
#  'мир': 2,
#  'мираж': 2,
#  'миша': 1,
#  'мишель': 1,
#  'мишка': 1,
#  'много': 3,
#  'мобель': 1,
#  'модель': 2,
#  'модерн': 12,
#  'модный': 7,
#  'модульный': 66,
#  'монако': 1,
#  'монарх': 2,
#  'монза': 1,
#  'моника': 1,
#  'монреаль': 5,
#  'монтилия': 1,
#  'моон': 3,
#  'морской': 1,
#  'москва': 327,
#  'московский': 1,
#  'мудульный': 1,
#  'мун': 1,
#  'мурано': 1,
#  'мюнхен': 3,
#  'мягкий': 60,
#  'надежда': 1,
#  'надувной': 31,
#  'накидка': 2,
#  'наличие': 4,
#  'наматрасник': 3,
#  'наполеон': 1,
#  'наполоть': 1,
#  'насос': 1,
#  'натуральный': 3,
#  'натяжной': 1,
#  'неаполь': 1,
#  'небольшой': 7,
#  'нега': 1,
#  'недорого': 261,
#  'недорогой': 62,
#  'независимый': 4,
#  'немецкий': 11,
#  'нео': 1,
#  'необычный': 9,
#  'неон': 1,
#  'нераскладной': 6,
#  'несси': 1,
#  'нестандартный': 2,
#  'нижний': 16,
#  'низкий': 6,
#  'ника': 1,
#  'ницца': 4,
#  'новгород': 13,
#  'новосибирск': 8,
#  'новочеркасск': 1,
#  'ножка': 6,
#  'норд': 1,
#  'норма': 1,
#  'нью': 1,
#  'обивка': 26,
#  'обивочный': 3,
#  'образный': 3,
#  'одежда': 1,
#  'односпальный': 2,
#  'ожидание': 3,
#  'окленд': 1,
#  'оливковый': 2,
#  'олль': 1,
#  'омск': 1,
#  'опт': 16,
#  'оптовый': 1,
#  'опус': 1,
#  'оранжевый': 3,
#  'орегон': 1,
#  'орел': 3,
#  'оригами': 1,
#  'оригинальный': 6,
#  'орион': 4,
#  'орматека': 2,
#  'ортопедический': 42,
#  'осло': 1,
#  'отдых': 1,
#  'отель': 3,
#  'отзыв': 12,
#  'офис': 70,
#  'офисный': 239,
#  'п': 3,
#  'паладин': 1,
#  'палермо': 7,
#  'панин': 1,
#  'пантограф': 5,
#  'париж': 1,
#  'парикмахерская': 3,
#  'парковый': 6,
#  'пенза': 1,
#  'пенополиуретан': 2,
#  'перевозка': 7,
#  'перетяжка': 29,
#  'пермь': 1,
#  'персиковый': 3,
#  'песочный': 3,
#  'петербург': 32,
#  'петрозаводск': 1,
#  'петропавловск': 2,
#  'пикколо': 1,
#  'питер': 2,
#  'плагин': 1,
#  'плаз': 3,
#  'плед': 5,
#  'плетеный': 11,
#  'плимут': 1,
#  'плюшевый': 1,
#  'подлокотник': 33,
#  'подростковый': 5,
#  'подросток': 1,
#  'подсветка': 1,
#  'подушка': 10,
#  'покрывало': 14,
#  'покрывать': 6,
#  'покупатель': 1,
#  'поливочный': 1,
#  'полиуретан': 2,
#  'поло': 1,
#  'полукруглый': 16,
#  'польша': 2,
#  'поменять': 3,
#  'популярный': 1,
#  'поролон': 1,
#  'посад': 1,
#  'посетитель': 4,
#  'почистить': 3,
#  'пошив': 13,
#  'пошить': 1,
#  'прага': 4,
#  'премиум': 6,
#  'премьер': 7,
#  'престиж': 1,
#  'приемная': 1,
#  'прима': 2,
#  'приобретать': 1,
#  'приставной': 1,
#  'прихожая': 2,
#  'провази': 2,
#  'прованс': 7,
#  'продажа': 20,
#  'производитель': 116,
#  'производство': 31,
#  'прокат': 1,
#  'профессиональный': 1,
#  'пружина': 2,
#  'пружинный': 32,
#  'прямой': 59,
#  'пума': 3,
#  'пуф': 1,
#  'работа': 1,
#  'размер': 10,
#  'раскладной': 69,
#  'раскладушка': 12,
#  'раскладываться': 1,
#  'распродажа': 18,
#  'рассрочка': 1,
#  'растаможка': 1,
#  'раут': 1,
#  'ребенок': 11,
#  'регулировать': 1,
#  'резинка': 7,
#  'рейн': 2,
#  'реклайнер': 3,
#  'релакс': 4,
#  'ремонт': 22,
#  'реставрация': 6,
#  'ресторан': 33,
#  'ригель': 2,
#  'рим': 3,
#  'римини': 1,
#  'розовый': 2,
#  'рококо': 1,
#  'рольф': 1,
#  'рондо': 2,
#  'роскошный': 1,
#  'россия': 3,
#  'ростов': 1,
#  'ротанг': 13,
#  'ротанговый': 1,
#  'ртуть': 1,
#  'рубль': 2,
#  'рука': 1,
#  'руководитель': 2,
#  'ручной': 1,
#  'рязань': 1,
#  'сlerk': 1,
#  'сабрина': 1,
#  'сад': 2,
#  'садовый': 4,
#  'сайт': 2,
#  'саксония': 1,
#  'салатовый': 2,
#  'салон': 7,
#  'самара': 9,
#  'саммит': 1,
#  'самурай': 2,
#  'самый': 6,
#  'сандра': 2,
#  'санкт': 22,
#  'сантьяго': 3,
#  'саратов': 1,
#  'сборка': 1,
#  'св': 6,
#  'светлана': 2,
#  'светящийся': 1,
#  'свой': 1,
#  'севилья': 1,
#  'седафлекс': 1,
#  'сезам': 1,
#  'секционный': 2,
#  'сенатор': 8,
#  'сергиев': 1,
#  'серенада': 2,
#  'серый': 10,
#  'сидение': 1,
#  'сидней': 1,
#  'синий': 2,
#  'синтепон': 1,
#  'сиреневый': 2,
#  'система': 5,
#  'сити': 5,
#  'скидка': 9,
#  'склад': 8,
#  'складный': 1,
#  'сколько': 6,
#  'сластик': 1,
#  'сливочный': 3,
#  'служба': 1,
#  'см': 1,
#  'смена': 1,
#  'сменить': 1,
#  'смоленск': 5,
#  'собака': 1,
#  'собирать': 1,
#  'современный': 25,
#  'соло': 1,
#  'солярис': 1,
#  'сон': 3,
#  'сопрано': 1,
#  'сорренто': 3,
#  'сосна': 2,
#  'состарить': 1,
#  'сотрудник': 1,
#  'софа': 11,
#  'софи': 7,
#  'софия': 10,
#  'сохо': 1,
#  'спальный': 119,
#  'спальня': 1,
#  'спать': 1,
#  'спб': 82,
#  'спейс': 2,
#  'спинка': 5,
#  'средний': 1,
#  'старина': 1,
#  'старинный': 3,
#  'старый': 1,
#  'стиль': 30,
#  'стильный': 20,
#  'стоимость': 13,
#  'стоить': 6,
#  'сток': 1,
#  'столик': 7,
#  'столлайн': 1,
#  'столплит': 1,
#  'страз': 2,
#  'стройдекор': 2,
#  'сунгирь': 1,
#  'сухой': 1,
#  'сша': 3,
#  'сшивать': 1,
#  'съемный': 1,
#  'тагил': 3,
#  'тайм': 1,
#  'так': 7,
#  'тахта': 6,
#  'тв': 3,
#  'телемагазин': 1,
#  'темно': 2,
#  'терракотовый': 1,
#  'тесло': 1,
#  'тетрис': 1,
#  'техас': 1,
#  'тибет': 4,
#  'тик': 7,
#  'тинос': 1,
#  'тироль': 1,
#  'титан': 1,
#  'тканевый': 12,
#  'ткань': 7,
#  'токио': 5,
#  'тонкий': 11,
#  'топпер': 2,
#  'торговый': 1,
#  'трамполь': 1,
#  'трансформация': 1,
#  'трансформер': 13,
#  'тренто': 1,
#  'трехместный': 14,
#  'трехсекционный': 1,
#  'тройной': 2,
#  'ттс': 1,
#  'тут': 1,
#  'тюмень': 1,
#  'у': 2,
#  'угловой': 557,
#  'уголок': 3,
#  'удобно': 1,
#  'удобный': 10,
#  'узкий': 19,
#  'ульяновск': 1,
#  'универсальный': 1,
#  'упить': 1,
#  'услуга': 1,
#  'утилизация': 1,
#  'уфа': 2,
#  'учреждение': 1,
#  'уют': 1,
#  'фабрика': 27,
#  'фаворит': 1,
#  'фагот': 1,
#  'феникс': 1,
#  'фиджи': 2,
#  'финский': 1,
#  'фиолетовый': 2,
#  'фирма': 2,
#  'фисташковый': 2,
#  'флок': 1,
#  'флора': 3,
#  'фолд': 2,
#  'форма': 5,
#  'фото': 70,
#  'фотопринт': 1,
#  'французский': 9,
#  'фрегат': 1,
#  'фултон': 1,
#  'функциональный': 1,
#  'футон': 2,
#  'х': 13,
#  'хабаровск': 3,
#  'хайтек': 2,
#  'хаки': 3,
#  'хартли': 1,
#  'хейфорд': 1,
#  'хилтон': 4,
#  'химчистка': 29,
#  'хирш': 1,
#  'хлопковый': 1,
#  'хлопок': 1,
#  'холдинг': 3,
#  'холл': 4,
#  'холофайбер': 1,
#  'хороший': 2,
#  'хорошо': 2,
#  'хранение': 5,
#  'хром': 1,
#  'царицыно': 2,
#  'цвет': 30,
#  'цветной': 1,
#  'цена': 184,
#  'центр': 1,
#  'чанг': 1,
#  'челябинск': 1,
#  'ченто': 1,
#  'через': 3,
#  'черно': 8,
#  'черный': 12,
#  'честер': 4,
#  'честерфилд': 3,
#  'чехол': 48,
#  'чикаго': 5,
#  'чистка': 19,
#  'чунг': 1,
#  'шале': 1,
#  'шанталь': 1,
#  'шанхай': 2,
#  'шатура': 1,
#  'шведский': 6,
#  'шедевр': 1,
#  'шезлонг': 1,
#  'шенилл': 1,
#  'широкий': 2,
#  'шланг': 1,
#  'шоколадный': 1,
#  'шоп': 2,
#  'эволюшен': 1,
#  'эгоист': 1,
#  'эдисон': 1,
#  'экзотика': 1,
#  'экокожий': 13,
#  'эконом': 25,
#  'эксклюзивный': 9,
#  'элегия': 8,
#  'элемент': 2,
#  'элиза': 1,
#  'элитный': 33,
#  'эммаус': 2,
#  'эркер': 1,
#  'эскиз': 1,
#  'этро': 1,
#  'этюд': 2,
#  'юлечка': 1,
#  'юлия': 1,
#  'юнитать': 1,
#  'юнона': 1,
#  'янтарный': 2,
#  'янтарь': 1,
#  'ярославль': 1,
#  'ярцево': 3,
#  'ящик': 19,
#  '\ufeff100': 1}

# %%
ngrams2
# Out:
# {('2', 'диван'): 28,
#  ('2', 'местный'): 15,
#  ('2', 'х'): 16,
#  ('3', 'диван'): 21,
#  ('3', 'х'): 16,
#  ('bo', 'box'): 22,
#  ('mobel', 'zeit'): 16,
#  ('v', 'диван'): 16,
#  ('аккордеон', 'диван'): 227,
#  ('аккордеон', 'купить'): 23,
#  ('аккордеон', 'недорого'): 18,
#  ('амстердам', 'диван'): 42,
#  ('английский', 'диван'): 15,
#  ('бар', 'диван'): 21,
#  ('без', 'диван'): 42,
#  ('без', 'подлокотник'): 52,
#  ('белоруссия', 'диван'): 34,
#  ('белорусский', 'диван'): 83,
#  ('белый', 'диван'): 83,
#  ('белый', 'кожаный'): 24,
#  ('белый', 'черно'): 19,
#  ('блок', 'диван'): 17,
#  ('блок', 'пружинный'): 40,
#  ('большой', 'диван'): 70,
#  ('большой', 'угловой'): 15,
#  ('борович', 'диван'): 36,
#  ('борович', 'мебель'): 19,
#  ('бостон', 'диван'): 18,
#  ('бристоль', 'диван'): 34,
#  ('бруклин', 'диван'): 19,
#  ('бу', 'диван'): 21,
#  ('выкатной', 'диван'): 139,
#  ('выкатной', 'купить'): 37,
#  ('германия', 'диван'): 26,
#  ('гостиная', 'диван'): 34,
#  ('двухместный', 'диван'): 80,
#  ('двухместный', 'купить'): 20,
#  ('двухместный', 'офисный'): 22,
#  ('дельфин', 'диван'): 34,
#  ('деревянный', 'диван'): 17,
#  ('деревянный', 'подлокотник'): 22,
#  ('детский', 'диван'): 346,
#  ('детский', 'купить'): 50,
#  ('детский', 'москва'): 19,
#  ('детский', 'недорого'): 17,
#  ('дешево', 'диван'): 164,
#  ('дешево', 'купить'): 45,
#  ('дешево', 'москва'): 20,
#  ('дешевый', 'диван'): 104,
#  ('дешевый', 'купить'): 16,
#  ('дешевый', 'офисный'): 16,
#  ('дешевый', 'угловой'): 19,
#  ('диван', 'дизайнерский'): 29,
#  ('диван', 'дом'): 36,
#  ('диван', 'домино'): 20,
#  ('диван', 'дорогой'): 42,
#  ('диван', 'еврокнижка'): 216,
#  ('диван', 'екатеринбург'): 24,
#  ('диван', 'заказ'): 86,
#  ('диван', 'заказывать'): 33,
#  ('диван', 'зеленый'): 24,
#  ('диван', 'изготовление'): 24,
#  ('диван', 'интернет'): 157,
#  ('диван', 'италия'): 85,
#  ('диван', 'итальянский'): 140,
#  ('диван', 'каталог'): 120,
#  ('диван', 'кафе'): 52,
#  ('диван', 'киев'): 33,
#  ('диван', 'китай'): 19,
#  ('диван', 'класс'): 17,
#  ('диван', 'классический'): 33,
#  ('диван', 'клерк'): 16,
#  ('диван', 'клик'): 81,
#  ('диван', 'кляк'): 44,
#  ('диван', 'книжка'): 192,
#  ('диван', 'кованый'): 25,
#  ('диван', 'кожа'): 51,
#  ('диван', 'кожаный'): 557,
#  ('диван', 'кожзам'): 72,
#  ('диван', 'красный'): 34,
#  ('диван', 'кресло'): 55,
#  ('диван', 'кровать'): 444,
#  ('диван', 'круглый'): 47,
#  ('диван', 'купить'): 1701,
#  ('диван', 'кухня'): 164,
#  ('диван', 'кухонный'): 238,
#  ('диван', 'лагуна'): 20,
#  ('диван', 'лион'): 16,
#  ('диван', 'магазин'): 197,
#  ('диван', 'мадрид'): 25,
#  ('диван', 'малайзия'): 24,
#  ('диван', 'маленький'): 131,
#  ('диван', 'малогабаритный'): 28,
#  ('диван', 'мальта'): 26,
#  ('диван', 'манхеттен'): 16,
#  ('диван', 'манчестер'): 17,
#  ('диван', 'марсель'): 23,
#  ('диван', 'матрас'): 48,
#  ('диван', 'мебель'): 170,
#  ('диван', 'местный'): 31,
#  ('диван', 'место'): 100,
#  ('диван', 'металлокаркас'): 19,
#  ('диван', 'метро'): 42,
#  ('диван', 'механизм'): 28,
#  ('диван', 'мини'): 42,
#  ('диван', 'модерн'): 24,
#  ('диван', 'модный'): 17,
#  ('диван', 'модульный'): 180,
#  ('диван', 'москва'): 405,
#  ('диван', 'мягкий'): 106,
#  ('диван', 'надувной'): 89,
#  ('диван', 'небольшой'): 15,
#  ('диван', 'недорого'): 473,
#  ('диван', 'недорогой'): 140,
#  ('диван', 'немецкий'): 27,
#  ('диван', 'необычный'): 23,
#  ('диван', 'нижний'): 22,
#  ('диван', 'низкий'): 16,
#  ('диван', 'обивка'): 74,
#  ('диван', 'опт'): 42,
#  ('диван', 'оригинальный'): 16,
#  ('диван', 'ортопедический'): 74,
#  ('диван', 'отзыв'): 18,
#  ('диван', 'офис'): 74,
#  ('диван', 'офисный'): 655,
#  ('диван', 'палермо'): 19,
#  ('диван', 'перевозка'): 19,
#  ('диван', 'перетяжка'): 71,
#  ('диван', 'петербург'): 46,
#  ('диван', 'плетеный'): 29,
#  ('диван', 'подлокотник'): 33,
#  ('диван', 'полукруглый'): 44,
#  ('диван', 'премьер'): 17,
#  ('диван', 'прованс'): 15,
#  ('диван', 'продажа'): 36,
#  ('диван', 'производитель'): 122,
#  ('диван', 'производство'): 65,
#  ('диван', 'пружинный'): 54,
#  ('диван', 'прямой'): 141,
#  ('диван', 'раскладной'): 155,
#  ('диван', 'раскладушка'): 20,
#  ('диван', 'распродажа'): 36,
#  ('диван', 'ремонт'): 48,
#  ('диван', 'ресторан'): 35,
#  ('диван', 'санкт'): 28,
#  ('диван', 'сенатор'): 22,
#  ('диван', 'серый'): 22,
#  ('диван', 'современный'): 59,
#  ('диван', 'софа'): 31,
#  ('диван', 'софия'): 24,
#  ('диван', 'спальный'): 157,
#  ('диван', 'спб'): 118,
#  ('диван', 'стиль'): 36,
#  ('диван', 'стильный'): 46,
#  ('диван', 'стоимость'): 31,
#  ('диван', 'тик'): 17,
#  ('диван', 'тканевый'): 32,
#  ('диван', 'трансформер'): 35,
#  ('диван', 'трехместный'): 28,
#  ('диван', 'угловой'): 1529,
#  ('диван', 'удобный'): 26,
#  ('диван', 'узкий'): 49,
#  ('диван', 'фабрика'): 53,
#  ('диван', 'фото'): 126,
#  ('диван', 'французский'): 19,
#  ('диван', 'химчистка'): 75,
#  ('диван', 'цвет'): 46,
#  ('диван', 'цена'): 332,
#  ('диван', 'черный'): 24,
#  ('диван', 'чехол'): 48,
#  ('диван', 'чистка'): 49,
#  ('диван', 'шведский'): 16,
#  ('диван', 'экокожий'): 23,
#  ('диван', 'эконом'): 55,
#  ('диван', 'эксклюзивный'): 23,
#  ('диван', 'элегия'): 20,
#  ('диван', 'элитный'): 79,
#  ('диван', 'ящик'): 19,
#  ('дом', 'цена'): 25,
#  ('еврокнижка', 'купить'): 24,
#  ('еврокнижка', 'недорого'): 15,
#  ('заказ', 'москва'): 16,
#  ('интернет', 'купить'): 42,
#  ('интернет', 'магазин'): 259,
#  ('интернет', 'недорого'): 15,
#  ('интернет', 'угловой'): 21,
#  ('итальянский', 'купить'): 24,
#  ('класс', 'эконом'): 40,
#  ('классический', 'стиль'): 19,
#  ('клик', 'кляк'): 94,
#  ('книжка', 'купить'): 34,
#  ('книжка', 'москва'): 18,
#  ('книжка', 'недорого'): 25,
#  ('кожаный', 'купить'): 74,
#  ('кожаный', 'москва'): 17,
#  ('кожаный', 'офисный'): 26,
#  ('кожаный', 'угловой'): 110,
#  ('кожаный', 'цена'): 25,
#  ('комната', 'маленький'): 22,
#  ('кресло', 'мебель'): 15,
#  ('кровать', 'купить'): 57,
#  ('кровать', 'недорого'): 27,
#  ('купить', 'кухня'): 22,
#  ('купить', 'кухонный'): 21,
#  ('купить', 'магазин'): 28,
#  ('купить', 'матрас'): 17,
#  ('купить', 'модульный'): 22,
#  ('купить', 'москва'): 149,
#  ('купить', 'надувной'): 21,
#  ('купить', 'недорого'): 159,
#  ('купить', 'недорогой'): 32,
#  ('купить', 'офисный'): 78,
#  ('купить', 'производитель'): 31,
#  ('купить', 'прямой'): 15,
#  ('купить', 'раскладной'): 15,
#  ('купить', 'спб'): 17,
#  ('купить', 'угловой'): 182,
#  ('кухня', 'маленький'): 36,
#  ('кухня', 'место'): 49,
#  ('кухня', 'недорого'): 20,
#  ('кухня', 'прямой'): 27,
#  ('кухня', 'раскладной'): 22,
#  ('кухня', 'спальный'): 54,
#  ('кухня', 'угловой'): 33,
#  ('кухня', 'узкий'): 15,
#  ('кухонный', 'место'): 16,
#  ('кухонный', 'спальный'): 26,
#  ('кухонный', 'угловой'): 43,
#  ('магазин', 'москва'): 19,
#  ('магазин', 'недорого'): 21,
#  ('магазин', 'угловой'): 29,
#  ('маленький', 'угловой'): 21,
#  ('матрас', 'ортопедический'): 54,
#  ('матрас', 'тонкий'): 25,
#  ('мебель', 'мягкий'): 57,
#  ('мебель', 'угловой'): 17,
#  ('местный', 'х'): 37,
#  ('место', 'недорого'): 19,
#  ('место', 'спальный'): 298,
#  ('место', 'угловой'): 25,
#  ('модульный', 'угловой'): 17,
#  ('москва', 'недорого'): 57,
#  ('москва', 'офисный'): 26,
#  ('москва', 'производитель'): 26,
#  ('москва', 'угловой'): 40,
#  ('мягкий', 'офисный'): 19,
#  ('мягкий', 'угловой'): 27,
#  ('недорого', 'офис'): 28,
#  ('недорого', 'офисный'): 28,
#  ('недорого', 'производитель'): 25,
#  ('недорого', 'спб'): 18,
#  ('недорого', 'угловой'): 74,
#  ('недорогой', 'угловой'): 21,
#  ('нижний', 'новгород'): 37,
#  ('офисный', 'офисный'): 31,
#  ('офисный', 'раскладной'): 24,
#  ('офисный', 'угловой'): 32,
#  ('петербург', 'санкт'): 64,
#  ('пошив', 'чехол'): 28,
#  ('производитель', 'спб'): 25,
#  ('производитель', 'угловой'): 29,
#  ('раскладушка', 'французский'): 16,
#  ('сколько', 'стоить'): 16,
#  ('спальный', 'угловой'): 43,
#  ('так', 'тик'): 19,
#  ('угловой', 'цена'): 42,
#  ('угловой', 'чехол'): 17}

# %% [markdown]
# # Поиск устойчивых словосочетаний
#
# Основная задача сервиса - получив семантику от оптимизатора, правилно выделить из неё теги и пометить ими запросы. Сложность состоит в том, что не все теги являются однословными, часто смысл тега теряется если разбить его на слова(например, "Roberto Cavalli" или "индивидуальный пошив"). Соответственно, необходимо найти подобные сочетания и считать их одним тегом.
#
# Оценка того, на сколько словосочетание является устойчивым основывается на частоте употребления отдельных слов из сочетания в запросах и частоте употребления всех слов из сочетания. Чем чаще слова идут вместе в одном запросе, тем выше вероятность что они составляют устойчивое сочетание и его нужно использовать как отдельный тег.
#
# Посчитать то, на сколько сочетание является устойчивым, можно используя гипергеометрическое распределение. <a href = 'http://ru.convdocs.org/pars_docs/refs/115/114050/114050_html_m6184011e.gif'>(формула)</a> для f = P(X = m), где:
#
# N - число ключевых слов для категории умноженное на бонус за то что слова встречаются вместе
# M - сколько раз всречается первое слово из анализируемой пары
# n - сколько раз встречается второе слово из анализируемой пары
# m или x - сколько раз встречается пара слов умножить на 1/(число ключевых слов для категории слов).
#
# используя все эти параметры, нужно найти значение CDF(cumulative distribution function) = F(m, n, M, N) = P(X <= m) гипергеометрического распределения для каждого тега с числом слов > 1.
#
# В итоге, для каждой пары слов получим оценку её "устойчивости". Самые устойчивые пары слов будем считать двусловными тегами. Для оценки словосочетаний из более чем двух слов, считается оценка для каждой пары слов из многословного сочетания и берётся среднее.
#
# Ниже реализация с использованием функции stats.hypergeom.cdf из модуля scipy.

# %%
#вероятности hypergeometric
def count_probs(indexn, index, comb_size, nkwords, bonus = 2):
    """
    indexn - список словосочетаний с оценками их встречаемости в запросах категории
    index - список отдельных слов с оценками их встречаемости
    comb_size - размер словосочетаний из indexn в словах
    nkwords - число ключевых слов в категории
    bonus - какой бонус за то что слова идут подряд использовался при оценке встречаемости слов
    
    возвращает список (словарь) {(словосочетание) : [сколько раз слово встречается, оценка устойчивости словосочетания]}
    """
    probs = {}
    #Для каждого словосочетания
    for ngram in indexn:
        if indexn[ngram] > 2:
            probs[ngram] = [indexn[ngram], 0]
            
            #все возможные комбинации чисел от 0 до comb_size, размера 2 (для того чтобы далее с помошью этих индексов
            #пройтись по всем возможным комбинациям из 2х слов в многословном сочетании)
            index_combs = [i for i in combinations(range(comb_size), 2)]
            for i, j in index_combs:
                cdf = stats.hypergeom.cdf(indexn[ngram]*(1/nkwords), nkwords*bonus, index[ngram[i]], index[ngram[j]])
                probs[ngram][1] += cdf
            probs[ngram][1] = probs[ngram][1]/len(index_combs)
            
    return probs

# %%
probs2 = count_probs(ngrams2, ngrams1, 2, len(qfile), bonus = 2)
probs3 = count_probs(ngrams3, ngrams1, 3, len(qfile), bonus = 2)

# %%
probs2
# Out:
# {('2', 'диван'): [28, 3.7631750768535268e-06],
#  ('2', 'местный'): [15, 0.95701310010030793],
#  ('2', 'х'): [16, 0.97317905676958527],
#  ('3', 'диван'): [21, 0.0001213351855131848],
#  ('3', 'х'): [16, 0.98056191743790289],
#  ('bo', 'box'): [22, 0.99259819395166526],
#  ('mobel', 'zeit'): [16, 0.99583068499031513],
#  ('v', 'диван'): [16, 0.015619557018940742],
#  ('аккордеон', 'диван'): [227, 2.8844639380241266e-25],
#  ('аккордеон', 'купить'): [23, 0.0002669031894416435],
#  ('аккордеон', 'недорого'): [18, 0.081948241459197102],
#  ('амстердам', 'диван'): [42, 1.5103555623434969e-05],
#  ('английский', 'диван'): [15, 0.0078061527999147354],
#  ('бар', 'диван'): [21, 1.8780885378820426e-06],
#  ('без', 'диван'): [42, 9.3718866595322713e-07],
#  ('без', 'подлокотник'): [52, 0.92609354728720406],
#  ('белоруссия', 'диван'): [34, 1.443536270822553e-08],
#  ('белорусский', 'диван'): [83, 4.443223667367826e-10],
#  ('белый', 'диван'): [83, 2.7377810802818081e-11],
#  ('белый', 'кожаный'): [24, 0.42291579549908292],
#  ('белый', 'черно'): [19, 0.96796978950668222],
#  ('блок', 'диван'): [17, 3.0252805038348251e-05],
#  ('блок', 'пружинный'): [40, 0.94570885390661785],
#  ('большой', 'диван'): [70, 8.9155015764345216e-10],
#  ('большой', 'угловой'): [15, 0.13439210176413577],
#  ('борович', 'диван'): [36, 6.0590075796315392e-05],
#  ('борович', 'мебель'): [19, 0.87756381246323378],
#  ('бостон', 'диван'): [18, 0.0039008111204575468],
#  ('бристоль', 'диван'): [34, 0.00024295254587922187],
#  ('бруклин', 'диван'): [19, 0.0078061527999147354],
#  ('бу', 'диван'): [21, 0.0019490470237593209],
#  ('выкатной', 'диван'): [139, 3.8729001457089026e-16],
#  ('выкатной', 'купить'): [37, 0.0056763543536157059],
#  ('германия', 'диван'): [26, 0.00024295254587922187],
#  ('гостиная', 'диван'): [34, 2.2141125037867307e-10],
#  ('двухместный', 'диван'): [80, 2.2141125037867307e-10],
#  ('двухместный', 'купить'): [20, 0.039122671085033936],
#  ('двухместный', 'офисный'): [22, 0.40608062677703],
#  ('дельфин', 'диван'): [34, 1.5103555623434969e-05],
#  ('деревянный', 'диван'): [17, 0.0001213351855131848],
#  ('деревянный', 'подлокотник'): [22, 0.95133721255104375],
#  ('детский', 'диван'): [346, 1.1632563363469621e-39],
#  ('детский', 'купить'): [50, 2.1695140374925079e-06],
#  ('детский', 'москва'): [19, 0.0068291703012098798],
#  ('детский', 'недорого'): [17, 0.0189808856437889],
#  ('дешево', 'диван'): [164, 5.8220914362374373e-25],
#  ('дешево', 'купить'): [45, 0.00029559017816048754],
#  ('дешево', 'москва'): [20, 0.044704929148523219],
#  ('дешевый', 'диван'): [104, 1.2731154994815196e-14],
#  ('дешевый', 'купить'): [16, 0.0094379960461983322],
#  ('дешевый', 'офисный'): [16, 0.27347330361569422],
#  ('дешевый', 'угловой'): [19, 0.045942915369175767],
#  ('диван', 'дизайнерский'): [29, 0.00048641347885798933],
#  ('диван', 'дом'): [36, 5.4960411214956455e-11],
#  ('диван', 'домино'): [20, 0.003900811120498436],
#  ('диван', 'дорогой'): [42, 3.7631750768420291e-06],
#  ('диван', 'еврокнижка'): [216, 9.6519960409906889e-24],
#  ('диван', 'екатеринбург'): [24, 3.7631750768420291e-06],
#  ('диван', 'заказ'): [86, 5.8220914362093072e-25],
#  ('диван', 'заказывать'): [33, 7.5394927908343976e-06],
#  ('диван', 'зеленый'): [24, 0.00097373149231397066],
#  ('диван', 'изготовление'): [24, 0.00097373149231397066],
#  ('диван', 'интернет'): [157, 5.4528574173831114e-32],
#  ('диван', 'италия'): [85, 4.1727316910426808e-13],
#  ('диван', 'итальянский'): [140, 1.925379479768527e-16],
#  ('диван', 'каталог'): [120, 1.1746911474095222e-17],
#  ('диван', 'кафе'): [52, 3.1498421555766415e-15],
#  ('диван', 'киев'): [33, 1.8780885378735689e-06],
#  ('диван', 'китай'): [19, 0.00048641347885798933],
#  ('диван', 'класс'): [17, 7.5394927908343976e-06],
#  ('диван', 'классический'): [33, 7.5394927908343976e-06],
#  ('диван', 'клерк'): [16, 0.015619557018947097],
#  ('диван', 'клик'): [81, 1.1031899320592954e-10],
#  ('диван', 'кляк'): [44, 5.4960411214956455e-11],
#  ('диван', 'книжка'): [192, 1.0711398409242816e-20],
#  ('диван', 'кованый'): [25, 0.0019490470237520606],
#  ('диван', 'кожа'): [51, 1.7887206407963714e-09],
#  ('диван', 'кожаный'): [557, 9.6429029252270484e-65],
#  ('диван', 'кожзам'): [72, 3.381731611973748e-12],
#  ('диван', 'красный'): [34, 6.0590075795999178e-05],
#  ('диван', 'кресло'): [55, 2.5590606138197875e-14],
#  ('диван', 'кровать'): [444, 4.683861046187149e-47],
#  ('диван', 'круглый'): [47, 7.5394927908343976e-06],
#  ('диван', 'купить'): [1701, 2.3847537693260015e-269],
#  ('диван', 'кухня'): [164, 1.5805002866081071e-49],
#  ('диван', 'кухонный'): [238, 2.1062826684098755e-27],
#  ('диван', 'лагуна'): [20, 0.003900811120498436],
#  ('диван', 'лион'): [16, 0.015619557018947097],
#  ('диван', 'магазин'): [197, 4.7868366086545851e-43],
#  ('диван', 'мадрид'): [25, 0.0019490470237520606],
#  ('диван', 'малайзия'): [24, 6.0590075795999178e-05],
#  ('диван', 'маленький'): [131, 1.3086370055429257e-21],
#  ('диван', 'малогабаритный'): [28, 0.00024295254587773296],
#  ('диван', 'мальта'): [26, 0.00097373149231397066],
#  ('диван', 'манхеттен'): [16, 0.015619557018947097],
#  ('диван', 'манчестер'): [17, 0.0078061527998444045],
#  ('диван', 'марсель'): [23, 0.0019490470237520606],
#  ('диван', 'матрас'): [48, 1.2731154994875986e-14],
#  ('диван', 'мебель'): [170, 5.8220914362093072e-25],
#  ('диван', 'местный'): [31, 4.6761378217186801e-07],
#  ('диван', 'место'): [100, 4.5179365977113158e-31],
#  ('диван', 'металлокаркас'): [19, 3.0252805038438426e-05],
#  ('диван', 'метро'): [42, 1.5103555623359687e-05],
#  ('диван', 'механизм'): [28, 2.3329040103655934e-07],
#  ('диван', 'мини'): [42, 1.5103555623359687e-05],
#  ('диван', 'модерн'): [24, 0.00024295254587773296],
#  ('диван', 'модный'): [17, 0.0078061527998444045],
#  ('диван', 'модульный'): [180, 1.0711398409242816e-20],
#  ('диван', 'москва'): [405, 6.4010704360916599e-102],
#  ('диван', 'мягкий'): [106, 7.1533538392366998e-19],
#  ('диван', 'надувной'): [89, 4.4432236674041956e-10],
#  ('диван', 'небольшой'): [15, 0.0078061527998444045],
#  ('диван', 'недорого'): [473, 4.9623302861309147e-81],
#  ('диван', 'недорогой'): [140, 1.7639828079857789e-19],
#  ('диван', 'немецкий'): [27, 0.00048641347885798933],
#  ('диван', 'необычный'): [23, 0.0019490470237520606],
#  ('диван', 'нижний'): [22, 1.5103555623359687e-05],
#  ('диван', 'низкий'): [16, 0.015619557018947097],
#  ('диван', 'обивка'): [74, 1.4435362708214452e-08],
#  ('диван', 'опт'): [42, 1.5103555623359687e-05],
#  ('диван', 'оригинальный'): [16, 0.015619557018947097],
#  ('диван', 'ортопедический'): [74, 2.0768834695874707e-13],
#  ('диван', 'отзыв'): [18, 0.00024295254587773296],
#  ('диван', 'офис'): [74, 6.491928930897257e-22],
#  ('диван', 'офисный'): [655, 4.0276691052108377e-74],
#  ('диван', 'палермо'): [19, 0.0078061527998444045],
#  ('диван', 'перевозка'): [19, 0.0078061527998444045],
#  ('диван', 'перетяжка'): [71, 1.7887206407963714e-09],
#  ('диван', 'петербург'): [46, 2.2141125037908527e-10],
#  ('диван', 'плетеный'): [29, 0.00048641347885798933],
#  ('диван', 'подлокотник'): [33, 1.1031899320592954e-10],
#  ('диван', 'полукруглый'): [44, 1.5103555623359687e-05],
#  ('диван', 'премьер'): [17, 0.0078061527998444045],
#  ('диван', 'прованс'): [15, 0.0078061527998444045],
#  ('диван', 'продажа'): [36, 9.3718866595278762e-07],
#  ('диван', 'производитель'): [122, 5.6470324829067671e-36],
#  ('диван', 'производство'): [65, 4.4432236674041956e-10],
#  ('диван', 'пружинный'): [54, 2.2141125037908527e-10],
#  ('диван', 'прямой'): [141, 1.4402579102862249e-18],
#  ('диван', 'раскладной'): [155, 1.3086370055429257e-21],
#  ('диван', 'раскладушка'): [20, 0.00024295254587773296],
#  ('диван', 'распродажа'): [36, 3.7631750768420291e-06],
#  ('диван', 'ремонт'): [48, 2.3329040103655934e-07],
#  ('диван', 'ресторан'): [35, 1.1031899320592954e-10],
#  ('диван', 'санкт'): [28, 2.3329040103655934e-07],
#  ('диван', 'сенатор'): [22, 0.003900811120498436],
#  ('диван', 'серый'): [22, 0.00097373149231397066],
#  ('диван', 'современный'): [59, 2.8948171962203356e-08],
#  ('диван', 'софа'): [31, 0.00048641347885798933],
#  ('диван', 'софия'): [24, 0.00097373149231397066],
#  ('диван', 'спальный'): [157, 6.7763091130497925e-37],
#  ('диван', 'спб'): [118, 1.4288920409487261e-25],
#  ('диван', 'стиль'): [36, 8.9155015763986664e-10],
#  ('диван', 'стильный'): [46, 9.3718866595278762e-07],
#  ('диван', 'стоимость'): [31, 0.00012133518551261105],
#  ('диван', 'тик'): [17, 0.0078061527998444045],
#  ('диван', 'тканевый'): [32, 0.00024295254587773296],
#  ('диван', 'трансформер'): [35, 0.00012133518551261105],
#  ('диван', 'трехместный'): [28, 6.0590075795999178e-05],
#  ('диван', 'угловой'): [1529, 1.1012948032644795e-176],
#  ('диван', 'удобный'): [26, 0.00097373149231397066],
#  ('диван', 'узкий'): [49, 1.8780885378735689e-06],
#  ('диван', 'фабрика'): [53, 7.1975296145813934e-09],
#  ('диван', 'фото'): [126, 6.491928930897257e-22],
#  ('диван', 'французский'): [19, 0.0019490470237520606],
#  ('диван', 'химчистка'): [75, 1.7887206407963714e-09],
#  ('диван', 'цвет'): [46, 8.9155015763986664e-10],
#  ('диван', 'цена'): [332, 5.7925887835982094e-57],
#  ('диван', 'черный'): [24, 0.00024295254587773296],
#  ('диван', 'чехол'): [48, 3.1498421555766415e-15],
#  ('диван', 'чистка'): [49, 1.8780885378735689e-06],
#  ('диван', 'шведский'): [16, 0.015619557018947097],
#  ('диван', 'экокожий'): [23, 0.00012133518551261105],
#  ('диван', 'эконом'): [55, 2.8948171962203356e-08],
#  ('диван', 'эксклюзивный'): [23, 0.0019490470237520606],
#  ('диван', 'элегия'): [20, 0.003900811120498436],
#  ('диван', 'элитный'): [79, 1.1031899320592954e-10],
#  ('диван', 'ящик'): [19, 1.8780885378735689e-06],
#  ('дом', 'цена'): [25, 0.47957139815729077],
#  ('еврокнижка', 'купить'): [24, 0.00044461111614809909],
#  ('еврокнижка', 'недорого'): [15, 0.095699029144930489],
#  ('заказ', 'москва'): [16, 0.044704929148523219],
#  ('интернет', 'купить'): [42, 2.8156033800795085e-05],
#  ('интернет', 'магазин'): [259, 0.18560883211085993],
#  ('интернет', 'недорого'): [15, 0.041366071850501542],
#  ('интернет', 'угловой'): [21, 0.00098673177767638924],
#  ('итальянский', 'купить'): [24, 0.0051273288304465071],
#  ('класс', 'эконом'): [40, 0.95179077982184113],
#  ('классический', 'стиль'): [19, 0.94241523373593539],
#  ('клик', 'кляк'): [94, 0.87754018037134418],
#  ('книжка', 'купить'): [34, 0.0012326057887370157],
#  ('книжка', 'москва'): [18, 0.077174024509818182],
#  ('книжка', 'недорого'): [25, 0.13047380017981366],
#  ('кожаный', 'купить'): [74, 5.0782910358323693e-10],
#  ('кожаный', 'москва'): [17, 0.00027968309417964317],
#  ('кожаный', 'офисный'): [26, 0.0026102267016414752],
#  ('кожаный', 'угловой'): [110, 7.2667087418847952e-07],
#  ('кожаный', 'цена'): [25, 0.010416292458188425],
#  ('комната', 'маленький'): [22, 0.90802665771399949],
#  ('кресло', 'мебель'): [15, 0.65667583970338983],
#  ('кровать', 'купить'): [57, 1.8383614703231035e-07],
#  ('кровать', 'недорого'): [27, 0.008965383597568639],
#  ('купить', 'кухня'): [22, 8.0613794583544705e-08],
#  ('купить', 'кухонный'): [21, 0.00013057108443111109],
#  ('купить', 'магазин'): [28, 7.0057879081608876e-07],
#  ('купить', 'матрас'): [17, 0.0094379960461232239],
#  ('купить', 'модульный'): [22, 0.0012326057887316207],
#  ('купить', 'москва'): [149, 2.2396305683232793e-15],
#  ('купить', 'надувной'): [21, 0.043301065098124238],
#  ('купить', 'недорого'): [159, 2.2670943844569325e-12],
#  ('купить', 'недорогой'): [32, 0.0018527175707800699],
#  ('купить', 'офисный'): [78, 2.2473980049993001e-11],
#  ('купить', 'производитель'): [31, 7.4324629032049153e-06],
#  ('купить', 'прямой'): [15, 0.0025147270976235824],
#  ('купить', 'раскладной'): [15, 0.00090787962886984238],
#  ('купить', 'спб'): [17, 0.00024099723649763214],
#  ('купить', 'угловой'): [182, 4.7478649163594465e-26],
#  ('кухня', 'маленький'): [36, 0.27317364788911652],
#  ('кухня', 'место'): [49, 0.15196685984707106],
#  ('кухня', 'недорого'): [20, 0.006978755206478479],
#  ('кухня', 'прямой'): [27, 0.32991198747869921],
#  ('кухня', 'раскладной'): [22, 0.27317364788911652],
#  ('кухня', 'спальный'): [54, 0.10597073236657539],
#  ('кухня', 'угловой'): [33, 2.0634483905024706e-05],
#  ('кухня', 'узкий'): [15, 0.70028036538660288],
#  ('кухонный', 'место'): [16, 0.35634517902715124],
#  ('кухонный', 'спальный'): [26, 0.29250217423172126],
#  ('кухонный', 'угловой'): [43, 0.0027181183322355536],
#  ('магазин', 'москва'): [19, 0.0044331103431612135],
#  ('магазин', 'недорого'): [21, 0.01346268533625597],
#  ('магазин', 'угловой'): [29, 8.6050577382712745e-05],
#  ('маленький', 'угловой'): [21, 0.0097845792279150582],
#  ('матрас', 'ортопедический'): [54, 0.7983444064875489],
#  ('матрас', 'тонкий'): [25, 0.94282137561393964],
#  ('мебель', 'мягкий'): [57, 0.57049789620763136],
#  ('мебель', 'угловой'): [17, 0.0046627796879301032],
#  ('местный', 'х'): [37, 0.96877400501692912],
#  ('место', 'недорого'): [19, 0.045412544486536949],
#  ('место', 'спальный'): [298, 0.24711513185970843],
#  ('место', 'угловой'): [25, 0.0012085846041754483],
#  ('модульный', 'угловой'): [17, 0.011974516789865972],
#  ('москва', 'недорого'): [57, 3.5366703205349948e-05],
#  ('москва', 'офисный'): [26, 8.496525794654433e-05],
#  ('москва', 'производитель'): [26, 0.01093464870006478],
#  ('москва', 'угловой'): [40, 2.1154136106448057e-10],
#  ('мягкий', 'офисный'): [19, 0.1840488449885789],
#  ('мягкий', 'угловой'): [27, 0.017930577834523207],
#  ('недорого', 'офис'): [28, 0.11526466285076198],
#  ('недорого', 'офисный'): [28, 0.00058052801786666124],
#  ('недорого', 'производитель'): [25, 0.027595601433268481],
#  ('недорого', 'спб'): [18, 0.079444027545865922],
#  ('недорого', 'угловой'): [74, 2.0393622906695343e-08],
#  ('недорогой', 'угловой'): [21, 0.015673391474802102],
#  ('нижний', 'новгород'): [37, 0.97612602173061647],
#  ('офисный', 'офисный'): [31, 0.0010978232469692805],
#  ('офисный', 'раскладной'): [24, 0.1426338698357886],
#  ('офисный', 'угловой'): [32, 9.2738345354403522e-08],
#  ('петербург', 'санкт'): [64, 0.92136090194020426],
#  ('пошив', 'чехол'): [28, 0.92994865784902858],
#  ('производитель', 'спб'): [25, 0.32758775121193751],
#  ('производитель', 'угловой'): [29, 0.00040940851369672366],
#  ('раскладушка', 'французский'): [16, 0.9875376620876124],
#  ('сколько', 'стоить'): [16, 0.99583068499031513],
#  ('спальный', 'угловой'): [43, 0.00033412386017136797],
#  ('так', 'тик'): [19, 0.99432871836737091],
#  ('угловой', 'цена'): [42, 4.01685424558993e-06],
#  ('угловой', 'чехол'): [17, 0.04016852779378971]}

# %%
probs3
# Out:
# {('2', 'диван', 'местный'): [13, 0.31900577696305565],
#  ('2', 'диван', 'х'): [12, 0.32443471837672494],
#  ('2', 'местный', 'х'): [16, 0.96632205396227411],
#  ('3', 'диван', 'местный'): [10, 0.32296526927281477],
#  ('3', 'диван', 'офисный'): [10, 0.23127644147509274],
#  ('3', 'диван', 'х'): [12, 0.32693486260297622],
#  ('3', 'местный', 'х'): [16, 0.97270330915799363],
#  ('3', 'офисный', 'х'): [10, 0.78932596530529586],
#  ('bo', 'box', 'диван'): [16, 0.33346660539752682],
#  ('mobel', 'zeit', 'диван'): [16, 0.34235659967606558],
#  ('аккордеон', 'дешево', 'диван'): [10, 0.15610474421721487],
#  ('аккордеон', 'диван', 'купить'): [39, 8.8967729813881167e-05],
#  ('аккордеон', 'диван', 'москва'): [11, 0.014331186801033617],
#  ('аккордеон', 'диван', 'недорого'): [18, 0.027316080486399035],
#  ('аккордеон', 'диван', 'недорогой'): [13, 0.18527408983786617],
#  ('аккордеон', 'диван', 'угловой'): [11, 0.001452910942383971],
#  ('без', 'диван', 'подлокотник'): [38, 0.3086981615287297],
#  ('белоруссия', 'диван', 'производство'): [11, 0.30349237025239029],
#  ('белоруссия', 'диван', 'угловой'): [13, 0.058566739783519707],
#  ('белорусский', 'диван', 'купить'): [28, 0.014433688514214504],
#  ('белорусский', 'диван', 'угловой'): [13, 0.041893255022837167],
#  ('белый', 'диван', 'кожаный'): [26, 0.14097193184215359],
#  ('белый', 'диван', 'фото'): [14, 0.25045018130885394],
#  ('белый', 'диван', 'черно'): [19, 0.32395686688485281],
#  ('блок', 'диван', 'пружинный'): [18, 0.31524636897768915],
#  ('большой', 'диван', 'угловой'): [15, 0.044797367551895312],
#  ('большой', 'место', 'спальный'): [10, 0.53666412126357621],
#  ('борович', 'диван', 'купить'): [13, 0.080882072615281922],
#  ('борович', 'диван', 'мебель'): [17, 0.29254146751301002],
#  ('бу', 'диван', 'офисный'): [16, 0.25944120219437067],
#  ('выкатной', 'дешево', 'диван'): [11, 0.20692067115312007],
#  ('выкатной', 'диван', 'купить'): [45, 0.0018921181178720313],
#  ('выкатной', 'диван', 'москва'): [16, 0.046127917746332951],
#  ('выкатной', 'диван', 'недорого'): [15, 0.069187306008587315],
#  ('двухместный', 'диван', 'кровать'): [13, 0.1884698251306853],
#  ('двухместный', 'диван', 'купить'): [16, 0.013040890435481728],
#  ('двухместный', 'диван', 'офисный'): [22, 0.1353602089994804],
#  ('детский', 'диван', 'кровать'): [26, 0.033628524799834782],
#  ('детский', 'диван', 'купить'): [72, 7.2317134583083592e-07],
#  ('детский', 'диван', 'магазин'): [16, 0.040983422255830335],
#  ('детский', 'диван', 'москва'): [21, 0.0022763901004032934],
#  ('детский', 'диван', 'недорого'): [23, 0.006326961881262967],
#  ('детский', 'диван', 'ортопедический'): [12, 0.17758287340933088],
#  ('детский', 'диван', 'спб'): [10, 0.097205161470929446],
#  ('детский', 'диван', 'цена'): [10, 0.020639226294736149],
#  ('дешево', 'диван', 'купить'): [47, 9.8530059386829174e-05],
#  ('дешево', 'диван', 'москва'): [14, 0.014901643049507739],
#  ('дешево', 'диван', 'офисный'): [27, 0.034803914394498259],
#  ('дешево', 'диван', 'угловой'): [22, 0.0015542598959767011],
#  ('дешевый', 'диван', 'купить'): [14, 0.0031459986820703543],
#  ('дешевый', 'диван', 'офисный'): [12, 0.091157767871902315],
#  ('дешевый', 'диван', 'угловой'): [19, 0.015314305123062833],
#  ('диван', 'дизайнерский', 'купить'): [10, 0.10972087609984109],
#  ('диван', 'дорогой', 'купить'): [14, 0.053927178456242425],
#  ('диван', 'дорогой', 'угловой'): [13, 0.10006577134800076],
#  ('диван', 'еврокнижка', 'купить'): [44, 0.0001482037053826997],
#  ('диван', 'еврокнижка', 'москва'): [13, 0.017418948006830661],
#  ('диван', 'еврокнижка', 'недорого'): [17, 0.031899676381643496],
#  ('диван', 'еврокнижка', 'угловой'): [10, 0.0020352922324354491],
#  ('диван', 'еврокнижка', 'цена'): [13, 0.064227932577464369],
#  ('диван', 'интернет', 'купить'): [36, 9.3853446002650279e-06],
#  ('диван', 'интернет', 'магазин'): [145, 0.06186961070361998],
#  ('диван', 'интернет', 'недорого'): [13, 0.013788690616833847],
#  ('диван', 'интернет', 'угловой'): [29, 0.00032891059255879643],
#  ('диван', 'италия', 'кожаный'): [10, 0.12159258084141626],
#  ('диван', 'италия', 'купить'): [21, 0.0052291773287662865],
#  ('диван', 'италия', 'угловой'): [10, 0.021422361854524466],
#  ('диван', 'итальянский', 'купить'): [30, 0.0017091096101488998],
#  ('диван', 'итальянский', 'угловой'): [10, 0.010234276746481171],
#  ('диван', 'итальянский', 'элитный'): [10, 0.27291001676720911],
#  ('диван', 'каталог', 'мебель'): [14, 0.19744031334324907],
#  ('диван', 'каталог', 'угловой'): [11, 0.0078215585078957508],
#  ('диван', 'каталог', 'фото'): [10, 0.21085445924939109],
#  ('диван', 'каталог', 'цена'): [14, 0.099207384470988202],
#  ('диван', 'киев', 'купить'): [13, 0.048730758480248854],
#  ('диван', 'киев', 'угловой'): [14, 0.093587233181302507],
#  ('диван', 'класс', 'эконом'): [32, 0.3172661160876013],
#  ('диван', 'клик', 'кляк'): [84, 0.2925133935122079],
#  ('диван', 'клик', 'купить'): [14, 0.011782345799010737],
#  ('диван', 'книжка', 'купить'): [52, 0.00041086859624567192],
#  ('диван', 'книжка', 'москва'): [20, 0.025724674836606062],
#  ('диван', 'книжка', 'недорого'): [25, 0.043491266726604555],
#  ('диван', 'книжка', 'недорогой'): [10, 0.20664810364657174],
#  ('диван', 'кожаный', 'купить'): [94, 1.6927636786107898e-10],
#  ('диван', 'кожаный', 'магазин'): [15, 0.01070051056286501],
#  ('диван', 'кожаный', 'москва'): [21, 9.3227698059881052e-05],
#  ('диван', 'кожаный', 'мягкий'): [10, 0.076072159548898385],
#  ('диван', 'кожаный', 'недорого'): [21, 0.00049891220726165414],
#  ('диван', 'кожаный', 'офисный'): [28, 0.00087007556721382506],
#  ('диван', 'кожаный', 'прямой'): [13, 0.077975329447505001],
#  ('диван', 'кожаный', 'угловой'): [118, 2.4222362472949317e-07],
#  ('диван', 'кожаный', 'цена'): [31, 0.0034720974860628084],
#  ('диван', 'кожаный', 'черный'): [10, 0.24834314317971626],
#  ('диван', 'кожзам', 'недорого'): [11, 0.10338984404448141],
#  ('диван', 'кожзам', 'офисный'): [24, 0.11427236656125019],
#  ('диван', 'кресло', 'мебель'): [11, 0.21889194656780511],
#  ('диван', 'кровать', 'круглый'): [16, 0.24628714498333623],
#  ('диван', 'кровать', 'купить'): [71, 6.1278715677436782e-08],
#  ('диван', 'кровать', 'недорого'): [29, 0.0029884611991895463],
#  ('диван', 'кровать', 'спб'): [10, 0.076990951341324346],
#  ('диван', 'кровать', 'угловой'): [16, 1.1855269568168649e-05],
#  ('диван', 'кровать', 'цена'): [13, 0.012193005718163764],
#  ('диван', 'купить', 'кухня'): [16, 2.6871264861181568e-08],
#  ('диван', 'купить', 'кухонный'): [29, 4.3523694810370361e-05],
#  ('диван', 'купить', 'магазин'): [30, 2.3352626360536293e-07],
#  ('диван', 'купить', 'матрас'): [11, 0.0031459986820453183],
#  ('диван', 'купить', 'модульный'): [30, 0.00041086859624387355],
#  ('диван', 'купить', 'москва'): [135, 7.4654352277442642e-16],
#  ('диван', 'купить', 'надувной'): [25, 0.014433688514148868],
#  ('диван', 'купить', 'недорого'): [163, 7.5569812815231082e-13],
#  ('диван', 'купить', 'недорогой'): [30, 0.00061757252359335676],
#  ('диван', 'купить', 'немецкий'): [10, 0.10972087609978659],
#  ('диван', 'купить', 'опт'): [10, 0.066041141338006079],
#  ('диван', 'купить', 'ортопедический'): [12, 0.0047239928507123137],
#  ('диван', 'купить', 'офис'): [11, 0.00027329444847820232],
#  ('диван', 'купить', 'офисный'): [98, 7.4913266833310003e-12],
#  ('диван', 'купить', 'петербург'): [15, 0.013040890435529728],
#  ('диван', 'купить', 'плетеный'): [10, 0.10972087609978659],
#  ('диван', 'купить', 'полукруглый'): [11, 0.066041141338006079],
#  ('диван', 'купить', 'производитель'): [23, 2.4774876344016383e-06],
#  ('диван', 'купить', 'прямой'): [25, 0.00083824236587452794],
#  ('диван', 'купить', 'раскладной'): [15, 0.00030262654295661414],
#  ('диван', 'купить', 'софа'): [10, 0.10972087609978659],
#  ('диван', 'купить', 'спб'): [19, 8.0332412165877386e-05],
#  ('диван', 'купить', 'трансформер'): [13, 0.089518579998707506],
#  ('диван', 'купить', 'угловой'): [234, 1.5826216387864823e-26],
#  ('диван', 'купить', 'цена'): [11, 2.2546568671738494e-09],
#  ('диван', 'купить', 'элитный'): [13, 0.011782345798959001],
#  ('диван', 'кухня', 'маленький'): [20, 0.091057882629705503],
#  ('диван', 'кухня', 'место'): [49, 0.050655619949023685],
#  ('диван', 'кухня', 'недорого'): [10, 0.0023262517354928265],
#  ('диван', 'кухня', 'прямой'): [15, 0.10997066249289973],
#  ('диван', 'кухня', 'раскладной'): [14, 0.091057882629705503],
#  ('диван', 'кухня', 'спальный'): [54, 0.035323577455525133],
#  ('диван', 'кухня', 'угловой'): [31, 6.8781613016749021e-06],
#  ('диван', 'кухня', 'узкий'): [13, 0.23342741449171359],
#  ('диван', 'кухонный', 'место'): [16, 0.11878172634238375],
#  ('диван', 'кухонный', 'прямой'): [16, 0.18160113639802988],
#  ('диван', 'кухонный', 'раскладной'): [10, 0.16376929318274211],
#  ('диван', 'кухонный', 'спальный'): [28, 0.097500724743907086],
#  ('диван', 'кухонный', 'угловой'): [49, 0.00090603944407851786],
#  ('диван', 'магазин', 'москва'): [13, 0.0014777034477204045],
#  ('диван', 'магазин', 'недорого'): [17, 0.0044875617787519901],
#  ('диван', 'магазин', 'офисный'): [11, 0.0064858245171632058],
#  ('диван', 'магазин', 'угловой'): [35, 2.8683525794237583e-05],
#  ('диван', 'маленький', 'место'): [12, 0.14855831307947784],
#  ('диван', 'маленький', 'раскладной'): [13, 0.19104761734330458],
#  ('диван', 'маленький', 'спальный'): [12, 0.12727501732673988],
#  ('диван', 'маленький', 'угловой'): [25, 0.0032615264093050194],
#  ('диван', 'малогабаритный', 'угловой'): [10, 0.14956858534071063],
#  ('диван', 'матрас', 'ортопедический'): [20, 0.26611480216258976],
#  ('диван', 'матрас', 'тонкий'): [11, 0.31443592969760342],
#  ('диван', 'мебель', 'мягкий'): [53, 0.1901659654025438],
#  ('диван', 'мебель', 'офисный'): [14, 0.034803914394498259],
#  ('диван', 'мебель', 'угловой'): [23, 0.0015542598959767011],
#  ('диван', 'мебель', 'фабрика'): [11, 0.25906255046954213],
#  ('диван', 'мебель', 'цена'): [10, 0.058871666612938071],
#  ('диван', 'местный', 'х'): [15, 0.32296526927207464],
#  ('диван', 'место', 'спальный'): [110, 0.08237171061990281],
#  ('диван', 'место', 'угловой'): [25, 0.00040286153472514943],
#  ('диван', 'метро', 'св'): [13, 0.33484956025134999],
#  ('диван', 'модульный', 'москва'): [12, 0.025724674836606062],
#  ('диван', 'модульный', 'недорого'): [10, 0.043491266726604555],
#  ('диван', 'модульный', 'система'): [10, 0.33118289859261962],
#  ('диван', 'модульный', 'угловой'): [25, 0.0039915055966219908],
#  ('диван', 'модульный', 'цена'): [16, 0.079834340868438658],
#  ('диван', 'москва', 'недорого'): [39, 1.1788901068449982e-05],
#  ('диван', 'москва', 'офисный'): [32, 2.8321752648848111e-05],
#  ('диван', 'москва', 'производитель'): [12, 0.0036448829000215936],
#  ('диван', 'москва', 'угловой'): [46, 7.0513787021493518e-11],
#  ('диван', 'мягкий', 'офисный'): [13, 0.061349614996192965],
#  ('диван', 'мягкий', 'угловой'): [27, 0.0059768592781744021],
#  ('диван', 'недорого', 'офис'): [10, 0.038421554283587324],
#  ('диван', 'недорого', 'офисный'): [36, 0.00019350933928888707],
#  ('диван', 'недорого', 'производитель'): [13, 0.0091985338110894942],
#  ('диван', 'недорого', 'угловой'): [110, 6.7978743022317808e-09],
#  ('диван', 'недорогой', 'угловой'): [23, 0.0052244638249340338],
#  ('диван', 'нижний', 'новгород'): [17, 0.32542082015725082],
#  ('диван', 'обивка', 'цена'): [19, 0.19008162398181441],
#  ('диван', 'офисный', 'офисный'): [41, 0.00036594108232309349],
#  ('диван', 'офисный', 'продажа'): [10, 0.18986072807530932],
#  ('диван', 'офисный', 'раскладной'): [28, 0.047544623278596203],
#  ('диван', 'офисный', 'спб'): [14, 0.032883464694716764],
#  ('диван', 'офисный', 'трехместный'): [10, 0.22483670151308985],
#  ('диван', 'офисный', 'угловой'): [34, 3.0912781784801172e-08],
#  ('диван', 'офисный', 'эконом'): [20, 0.16490480565379348],
#  ('диван', 'перетяжка', 'угловой'): [10, 0.04790241184820223],
#  ('диван', 'перетяжка', 'цена'): [15, 0.17813340924118429],
#  ('диван', 'петербург', 'санкт'): [30, 0.30712037848400553],
#  ('диван', 'пошив', 'чехол'): [10, 0.31002333101151475],
#  ('диван', 'продажа', 'угловой'): [10, 0.087527668105098558],
#  ('диван', 'производитель', 'спб'): [11, 0.10919591707064584],
#  ('диван', 'производитель', 'угловой'): [27, 0.00013646950456557455],
#  ('диван', 'производство', 'угловой'): [13, 0.041893255022837167],
#  ('диван', 'раскладушка', 'французский'): [10, 0.32990988721908071],
#  ('диван', 'спальный', 'угловой'): [45, 0.00011137462005712265],
#  ('диван', 'спб', 'угловой'): [16, 0.0013581595789413784],
#  ('диван', 'так', 'тик'): [17, 0.33664700798901986],
#  ('диван', 'тканевый', 'угловой'): [13, 0.14956858534071063],
#  ('диван', 'угловой', 'фото'): [13, 0.0030491248882307509],
#  ('диван', 'угловой', 'цена'): [58, 1.3389514151966434e-06],
#  ('диван', 'угловой', 'чехол'): [17, 0.013389509264597621],
#  ('диван', 'угловой', 'элитный'): [13, 0.036636739447783902],
#  ('интернет', 'кожаный', 'магазин'): [10, 0.098786212425985787],
#  ('интернет', 'купить', 'магазин'): [34, 0.06187922957448385],
#  ('интернет', 'магазин', 'москва'): [15, 0.069412236359070192],
#  ('интернет', 'магазин', 'недорого'): [19, 0.080145863099205808],
#  ('интернет', 'магазин', 'угловой'): [22, 0.062227204821973005],
#  ('клик', 'кляк', 'купить'): [12, 0.31494086707079183],
#  ('клик', 'кляк', 'недорого'): [13, 0.53013389620687867],
#  ('кожаный', 'купить', 'угловой'): [20, 2.4239290109735424e-07],
#  ('купить', 'москва', 'недорого'): [14, 1.1788901824894653e-05],
#  ('купить', 'москва', 'угловой'): [15, 7.0514533565016313e-11],
#  ('купить', 'недорого', 'угловой'): [28, 6.7986300003599333e-09],
#  ('кухня', 'место', 'спальный'): [51, 0.16835090802445163],
#  ('кухня', 'спальный', 'угловой'): [10, 0.03544183023688393],
#  ('кухонный', 'место', 'спальный'): [16, 0.29865416170619369],
#  ('маленький', 'место', 'спальный'): [12, 0.35820504102612055],
#  ('матрас', 'ортопедический', 'тонкий'): [13, 0.8962795088780986],
#  ('мебель', 'мягкий', 'офисный'): [10, 0.28631949479323499],
#  ('место', 'недорого', 'спальный'): [19, 0.10588663223285576],
#  ('место', 'спальный', 'угловой'): [25, 0.082885946774685082],
#  ('москва', 'недорого', 'угловой'): [10, 1.1795769456539234e-05]}

# %%
#Можно сразу удалить словосочетания с оценкой встречаемости ниже 0.75
def cut_low_pr(probs, cut = 0.75):
    probs_clean = {}
    for ngram in probs:
        if probs[ngram][1] > cut:
            probs_clean[ngram] = probs[ngram]
    return probs_clean

probs2_high = cut_low_pr(probs2)
probs3_high = cut_low_pr(probs3)

# %%
#отсортированные по устойчивости словосочетания
sorted(probs3_high.items(), key=lambda x:x[1][1], reverse=True)
# Out:
# [(('3', 'местный', 'х'), [16, 0.97270330915799363]),
#  (('2', 'местный', 'х'), [16, 0.96632205396227411]),
#  (('матрас', 'ортопедический', 'тонкий'), [13, 0.8962795088780986]),
#  (('3', 'офисный', 'х'), [10, 0.78932596530529586])]

# %%
#отсортированные по устойчивости словосочетания
sorted(probs2_high.items(), key=lambda x:x[1][1], reverse=True)
# Out:
# [(('сколько', 'стоить'), [16, 0.99583068499031513]),
#  (('mobel', 'zeit'), [16, 0.99583068499031513]),
#  (('так', 'тик'), [19, 0.99432871836737091]),
#  (('bo', 'box'), [22, 0.99259819395166526]),
#  (('раскладушка', 'французский'), [16, 0.9875376620876124]),
#  (('3', 'х'), [16, 0.98056191743790289]),
#  (('нижний', 'новгород'), [37, 0.97612602173061647]),
#  (('2', 'х'), [16, 0.97317905676958527]),
#  (('местный', 'х'), [37, 0.96877400501692912]),
#  (('белый', 'черно'), [19, 0.96796978950668222]),
#  (('2', 'местный'), [15, 0.95701310010030793]),
#  (('класс', 'эконом'), [40, 0.95179077982184113]),
#  (('деревянный', 'подлокотник'), [22, 0.95133721255104375]),
#  (('блок', 'пружинный'), [40, 0.94570885390661785]),
#  (('матрас', 'тонкий'), [25, 0.94282137561393964]),
#  (('классический', 'стиль'), [19, 0.94241523373593539]),
#  (('пошив', 'чехол'), [28, 0.92994865784902858]),
#  (('без', 'подлокотник'), [52, 0.92609354728720406]),
#  (('петербург', 'санкт'), [64, 0.92136090194020426]),
#  (('комната', 'маленький'), [22, 0.90802665771399949]),
#  (('борович', 'мебель'), [19, 0.87756381246323378]),
#  (('клик', 'кляк'), [94, 0.87754018037134418]),
#  (('матрас', 'ортопедический'), [54, 0.7983444064875489])]

# %% [markdown]
# # Разметка запросов тегами
#
# После того как были определены популярные двусловные и трехсловные теги, необходимо для каждого запроса обозначить список тегов к которым он принадлежит.
#
# Для этого просто определяем встречаются ли все слова из тега в запросе (включая однословные теги).
#
# Если к запросу привязаны однословные теги, входящие в состав многословных тегов, составляют устойчивое сочетание которое тоже привязано к запросу, необходимо удалить однословные теги и оставить только много словные. Такой же принцип распространяется к двусловным тегам по отношению к трёхсловным, удаляем двусловники которые есть в составе треёсловного тега привязанного к запросу.
#
# Если к запросу возможно привзать более одного многословного тега, необходимо это сделать, даже если одно слово из запроса встречается в нескольких многословных тегах и не понятно к какому из них оно относится.

# %%
def tag(query, tags):
    L = [] 
    if type(tags[0]) is str:
        for word in query.split():
            if word in tags:
                L.append(word)
   
    elif len(tags[0]) == 2:
        terms = query.split()
        terms.sort()
        for comb in combinations(terms, 2):
            if comb in tags:
                L.append(comb)
    
    elif len(tags[0]) == 3:
        terms = query.split()
        terms.sort()
        for comb in combinations(terms, 3):
            if comb in tags:
                L.append(comb)
    return L
    

def tag_queries(queries, tags1w, tags2w, tags3w):
    tagged = {}
    for query in queries:
        qtags1, qtags1_iter = tag(query, tags1w), tag(query, tags1w)
        qtags2, qtags2_iter = tag(query, tags2w), tag(query, tags2w)
        qtags3, qtags3_iter = tag(query, tags3w), tag(query, tags3w)
        for tag1 in qtags1_iter:
            for tag2 in qtags2:
                if tag1 in tag2:
                    try:
                        qtags1.remove(tag1)
                    except:
                        pass
                    break
           
        for tag1 in qtags1_iter:
            for tag3 in qtags3:
                if tag1 in tag3:
                    try:
                        qtags1.remove(tag1)
                    except:
                        pass
                    break
                    
        if len(qtags3) > 0:
            for tag2 in qtags2_iter:
                for tag3 in qtags3:
                    if tag2[0] in tag3 and tag2[1] in tag3:
                        try:
                            qtags2.remove(tag2)
                        except:
                            pass
                        break
        tagged[query] = [qtags1, qtags2, qtags3]            
    return tagged

# %%
ngrams1frequent = {}
for word in ngrams1:
    if ngrams1[word] > 2:
        ngrams1frequent[word] = ngrams1[word]

# %%
#таблица с ключевиками и тегами
tagged = pd.DataFrame.from_dict(tag_queries(qfile, 
            list(ngrams1frequent.keys()), list(probs2_high.keys()), list(probs3_high.keys())), orient = 'index')

# %% [markdown]
# # Результат работы сервиса
#
# (разница только в том, что на выходе нужно ещё привязать к исходным словоформам сами ключевые слова, которые были лемматизированы в сомом начале)

# %%
#Важно! Если есть многословный тег, то есдиничных слов из него нет в списке однословных тегов
#и если это тег из 3х слов, то пар слов из него нет в списке двусловных тегов
tagged.iloc[950:1000]
# Out:
#                                                                                        0  \
# диван дельфин купить в москва                           [диван, дельфин, купить, москва]
# диван трансформер купить                                    [диван, трансформер, купить]
# лион диван                                                                 [лион, диван]
# диван ростов на дон                                                              [диван]
# ортопедический матрас для диван                                                  [диван]
# палермо диван                                                           [палермо, диван]
# диван для бар ресторан                                            [диван, бар, ресторан]
# офисный диван сандра                                                    [офисный, диван]
# купить угловой диван от производитель            [купить, угловой, диван, производитель]
# диван карпентер                                                                  [диван]
# кухонный диван на заказ                                         [кухонный, диван, заказ]
# диван где купить                                                         [диван, купить]
# диван петербург                                                       [диван, петербург]
# угловой белый кожаный диван                             [угловой, белый, кожаный, диван]
# кухонный диван со спальный место недорого   [кухонный, диван, спальный, место, недорого]
# диван производство малайзия                              [диван, производство, малайзия]
# диван 3 х местный бизон                                                   [диван, бизон]
# вывоз диван                                                                      [диван]
# недорого диван                                                         [недорого, диван]
# диван сенатор св                                                    [диван, сенатор, св]
# купить белый кожаный диван                               [купить, белый, кожаный, диван]
# диван выкатной                                                         [диван, выкатной]
# угловой кухонный диван для маленький кухня  [угловой, кухонный, диван, маленький, кухня]
# кровать борович двухъярусный с диван             [кровать, борович, двухъярусный, диван]
# диван без подлокотник недорого                                         [диван, недорого]
# обивка диван цена                                                  [обивка, диван, цена]
# диван для кабинет раскладной                                [диван, кабинет, раскладной]
# чехол на угловой диван в икеа                              [чехол, угловой, диван, икеа]
# модульный кожаный диван                                      [модульный, кожаный, диван]
# диван для подросток                                                              [диван]
# купить детский угловой диван                           [купить, детский, угловой, диван]
# угловой диван интернет магазин                       [угловой, диван, интернет, магазин]
# дешевый диван кровать                                          [дешевый, диван, кровать]
# современный диван купить                                    [современный, диван, купить]
# диван милфорд                                                                    [диван]
# диван в петербург                                                     [диван, петербург]
# обивочный ткань для диван каталог                     [обивочный, ткань, диван, каталог]
# диван сопрано                                                                    [диван]
# круглый диван фото                                                [круглый, диван, фото]
# tanagra диван                                                                    [диван]
# кухонный диван москва                                          [кухонный, диван, москва]
# пошив чехол для диван икеа                                                 [диван, икеа]
# перетяжка диван дешево                                        [перетяжка, диван, дешево]
# купить немецкий диван                                          [купить, немецкий, диван]
# диван кровать купить недорого                         [диван, кровать, купить, недорого]
# красивый современный диван                                          [современный, диван]
# диван офисный домино                                            [диван, офисный, домино]
# офисный офисный диван и кресло                         [офисный, офисный, диван, кресло]
# обивка диван                                                             [обивка, диван]
# выкатной диван цена                                              [выкатной, диван, цена]
#
#                                                                      1  \
# диван дельфин купить в москва                                       []
# диван трансформер купить                                            []
# лион диван                                                          []
# диван ростов на дон                                                 []
# ортопедический матрас для диван             [(матрас, ортопедический)]
# палермо диван                                                       []
# диван для бар ресторан                                              []
# офисный диван сандра                                                []
# купить угловой диван от производитель                               []
# диван карпентер                                                     []
# кухонный диван на заказ                                             []
# диван где купить                                                    []
# диван петербург                                                     []
# угловой белый кожаный диван                                         []
# кухонный диван со спальный место недорого                           []
# диван производство малайзия                                         []
# диван 3 х местный бизон                                             []
# вывоз диван                                                         []
# недорого диван                                                      []
# диван сенатор св                                                    []
# купить белый кожаный диван                                          []
# диван выкатной                                                      []
# угловой кухонный диван для маленький кухня                          []
# кровать борович двухъярусный с диван                                []
# диван без подлокотник недорого                    [(без, подлокотник)]
# обивка диван цена                                                   []
# диван для кабинет раскладной                                        []
# чехол на угловой диван в икеа                                       []
# модульный кожаный диван                                             []
# диван для подросток                                                 []
# купить детский угловой диван                                        []
# угловой диван интернет магазин                                      []
# дешевый диван кровать                                               []
# современный диван купить                                            []
# диван милфорд                                                       []
# диван в петербург                                                   []
# обивочный ткань для диван каталог                                   []
# диван сопрано                                                       []
# круглый диван фото                                                  []
# tanagra диван                                                       []
# кухонный диван москва                                               []
# пошив чехол для диван икеа                            [(пошив, чехол)]
# перетяжка диван дешево                                              []
# купить немецкий диван                                               []
# диван кровать купить недорого                                       []
# красивый современный диван                                          []
# диван офисный домино                                                []
# офисный офисный диван и кресло                                      []
# обивка диван                                                        []
# выкатной диван цена                                                 []
#
#                                                             2
# диван дельфин купить в москва                              []
# диван трансформер купить                                   []
# лион диван                                                 []
# диван ростов на дон                                        []
# ортопедический матрас для диван                            []
# палермо диван                                              []
# диван для бар ресторан                                     []
# офисный диван сандра                                       []
# купить угловой диван от производитель                      []
# диван карпентер                                            []
# кухонный диван на заказ                                    []
# диван где купить                                           []
# диван петербург                                            []
# угловой белый кожаный диван                                []
# кухонный диван со спальный место недорого                  []
# диван производство малайзия                                []
# диван 3 х местный бизон                     [(3, местный, х)]
# вывоз диван                                                []
# недорого диван                                             []
# диван сенатор св                                           []
# купить белый кожаный диван                                 []
# диван выкатной                                             []
# угловой кухонный диван для маленький кухня                 []
# кровать борович двухъярусный с диван                       []
# диван без подлокотник недорого                             []
# обивка диван цена                                          []
# диван для кабинет раскладной                               []
# чехол на угловой диван в икеа                              []
# модульный кожаный диван                                    []
# диван для подросток                                        []
# купить детский угловой диван                               []
# угловой диван интернет магазин                             []
# дешевый диван кровать                                      []
# современный диван купить                                   []
# диван милфорд                                              []
# диван в петербург                                          []
# обивочный ткань для диван каталог                          []
# диван сопрано                                              []
# круглый диван фото                                         []
# tanagra диван                                              []
# кухонный диван москва                                      []
# пошив чехол для диван икеа                                 []
# перетяжка диван дешево                                     []
# купить немецкий диван                                      []
# диван кровать купить недорого                              []
# красивый современный диван                                 []
# диван офисный домино                                       []
# офисный офисный диван и кресло                             []
# обивка диван                                               []
# выкатной диван цена                                        []
